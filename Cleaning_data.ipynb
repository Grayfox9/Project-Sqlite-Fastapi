# %% [markdown]
# # Proyecto Individual 1: Chequeo y Limpieza de datos

# %%
# Importando las librerías para leer los archivos .json
import pandas as pd
import numpy as np

# %% [markdown]
# ### Normalizando el Dataset: constructors.json

# %%
constructors_df = pd.read_json(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\constructors.json",
                                lines = True, encoding = 'utf-8')

# %%
constructors_df
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            209          manor  Manor Marussia     British
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# ...

# %%
#Realizamos un chequeo de valores nulos y duplicados.
constructors_df.isnull().sum()
# Out:
# constructorId     0
# constructorRef    0
# name              0
# nationality       0
# url               0
# dtype: int64

# %%
#Convirtiendo a .csv
constructors_df.to_csv('constructors.csv', index=False)

# %% [markdown]
# ### Normalizando el Dataset: drivers.json

# %%
drivers_df = pd.read_json(r"C:\Users\Mimar\Desktop\Projects\I1\Datasets\drivers.json",
                                lines = True, encoding = 'utf-8')

# %%
drivers_df
# Out:
#      driverId          driverRef number code  \
# 0           1           hamilton     44  HAM
# 1           2           heidfeld     \N  HEI
# 2           3            rosberg      6  ROS
# 3           4             alonso     14  ALO
# 4           5         kovalainen     \N  KOV
# ..        ...                ...    ...  ...
# 848       850  pietro_fittipaldi     51  FIT
# 849       851             aitken     89  AIT
# 850       852            tsunoda     \N  TSU
# 851       853            mazepin     \N  MAZ
# 852       854    mick_schumacher     \N  SCH
#
#                                                 name         dob nationality  \
# 0       {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1        {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
# 2         {'forename': 'Nico', 'surname': 'Rosberg'}  1985-06-27      German
# 3      {'forename': 'Fernando', 'surname': 'Alonso'}  1981-07-29     Spanish
# ...

# %%
#Vemos que en la columna "names" aparecen en formato de diccionario y pasamos a extraer los nombres de cada una de las filas.
drivers_df = pd.concat([drivers_df, drivers_df["name"].apply(pd.Series)], axis=1)

# %%
#drivers_df = drivers_df.drop(columns= "name")
drivers_df
# Out:
#      driverId          driverRef number code         dob nationality  \
# 0           1           hamilton     44  HAM  1985-01-07     British
# 1           2           heidfeld     \N  HEI  1977-05-10      German
# 2           3            rosberg      6  ROS  1985-06-27      German
# 3           4             alonso     14  ALO  1981-07-29     Spanish
# 4           5         kovalainen     \N  KOV  1981-10-19     Finnish
# ..        ...                ...    ...  ...         ...         ...
# 848       850  pietro_fittipaldi     51  FIT  1996-06-25   Brazilian
# 849       851             aitken     89  AIT  1995-09-23     British
# 850       852            tsunoda     \N  TSU  2000-05-11    Japanese
# 851       853            mazepin     \N  MAZ  1999-03-02     Russian
# 852       854    mick_schumacher     \N  SCH  1999-03-22      German
#
#                                                 url  forename     surname
# ...

# %%
#Realizamos un chequeo de valores nulos y duplicados.
drivers_df.isnull().sum()
# Out:
# driverId       0
# driverRef      0
# number         0
# code           0
# dob            0
# nationality    0
# url            0
# forename       0
# surname        0
# dtype: int64

# %%
#Reemplazamos los valores "\N"

drivers_df = drivers_df.replace("\\N", "NoData")
drivers_df
# Out:
#      driverId          driverRef  number code         dob nationality  \
# 0           1           hamilton      44  HAM  1985-01-07     British
# 1           2           heidfeld  NoData  HEI  1977-05-10      German
# 2           3            rosberg       6  ROS  1985-06-27      German
# 3           4             alonso      14  ALO  1981-07-29     Spanish
# 4           5         kovalainen  NoData  KOV  1981-10-19     Finnish
# ..        ...                ...     ...  ...         ...         ...
# 848       850  pietro_fittipaldi      51  FIT  1996-06-25   Brazilian
# 849       851             aitken      89  AIT  1995-09-23     British
# 850       852            tsunoda  NoData  TSU  2000-05-11    Japanese
# 851       853            mazepin  NoData  MAZ  1999-03-02     Russian
# 852       854    mick_schumacher  NoData  SCH  1999-03-22      German
#
#                                                 url  forename     surname
# ...

# %%
#Convirtiendo a .csv
drivers_df.to_csv('drivers.csv', index=False)

# %% [markdown]
# ### Normalizando el Dataset: pit_stops.json

# %%
PitStops_df = pd.read_json(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\pit_stops.json",
                                 orient = 'values')

# %%
PitStops_df
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds
# 0        841       153     1    1  17:05:23   26.898         26898
# 1        841        30     1    1  17:05:52   25.021         25021
# 2        841        17     1   11  17:20:48   23.426         23426
# 3        841         4     1   12  17:22:34   23.251         23251
# 4        841        13     1   13  17:24:10   23.842         23842
# ...      ...       ...   ...  ...       ...      ...           ...
# 8025    1047        20     1   35  18:17:15    22.04         22040
# 8026    1047       849     2   35  18:17:41   22.384         22384
# 8027    1047       817     1   39  18:23:37   22.123         22123
# 8028    1047       825     2   47  18:39:11   23.098         23098
# 8029    1047       850     3   48  18:41:11   23.217         23217
#
# [8030 rows x 7 columns]

# %%
#Realizamos un chequeo de valores nulos y duplicados.
PitStops_df.isnull().sum()
# Out:
# raceId          0
# driverId        0
# stop            0
# lap             0
# time            0
# duration        0
# milliseconds    0
# dtype: int64

# %%
#Convirtiendo a .csv
PitStops_df.to_csv('pitstops.csv', index=False)

# %% [markdown]
# ### Normalizando el Dataset: results.json

# %%
results_df = pd.read_json(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\results.json",
                                lines = True, encoding = 'utf-8')

# %%
results_df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 24955     24961    1047       841             51     99    14       16
# 24956     24962    1047       849              3      6    18       17
# 24957     24963    1047       825            210     20    20       18
# 24958     24964    1047       850            210     51    17       19
# 24959     24965    1047       815            211     11    19       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
#A vista simple se observa que hay entradas de forma "\N". Realizamos un chequeo de valores nulos y duplicados
results_df.isnull().sum()
# Out:
# resultId           0
# raceId             0
# driverId           0
# constructorId      0
# number             0
# grid               0
# position           0
# positionText       0
# positionOrder      0
# points             0
# laps               0
# time               0
# milliseconds       0
# fastestLap         0
# rank               0
# fastestLapTime     0
# fastestLapSpeed    0
# statusId           0
# dtype: int64

# %%
#Reemplazamos los valores "\N"

results_df = results_df.replace("\\N", "NoData")

# %%
#Convertimos el Dataframe a csv

results_df.to_csv('results.csv', index=False)

# %% [markdown]
# ### Normalizando el Dataset: circuits.csv

# %%
circuits_df = pd.read_csv(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\circuits.csv",
                                )

# %%
circuits_df
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         73          BAK                     Baku City Circuit
# 73         74        hanoi                  Hanoi Street Circuit
# 74         75     portimao    Autódromo Internacional do Algarve
# 75         76      mugello  Autodromo Internazionale del Mugello
# 76         77       jeddah                 Jeddah Street Circuit
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# ...

# %%
#Realizamos un chequeo de valores nulos y duplicados.
circuits_df.isnull().sum()
# Out:
# circuitId     0
# circuitRef    0
# name          0
# location      0
# country       0
# lat           0
# lng           0
# alt           0
# url           0
# dtype: int64

# %%
#Vemos que no tiene valores nules o faltantes por lo que lo dejamos tal cual

# %% [markdown]
# ### Normalizando el Dataset: races.csv

# %%
races_df = pd.read_csv(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\races.csv",
                                )

# %%
races_df
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 0          1  2009      1          1     Australian Grand Prix  2009-03-29
# 1          2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4        Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                       ...         ...
# 1053    1069  2021     18         69  United States Grand Prix  2021-10-24
# 1054    1070  2021     19         32    Mexico City Grand Prix  2021-10-31
# 1055    1071  2021     20         18      Brazilian Grand Prix  2021-11-07
# 1056    1072  2021     22         77  Saudi Arabian Grand Prix  2021-12-05
# 1057    1073  2021     23         24      Abu Dhabi Grand Prix  2021-12-12
#
#           time                                                url
# ...

# %%
#Buscamos valores nulos
races_df.isnull().sum()
# Out:
# raceId       0
# year         0
# round        0
# circuitId    0
# name         0
# date         0
# time         0
# url          0
# dtype: int64

# %%
#Buscamos valores de forma "\N"
'\\N' in races_df.values
# Out:
# True

# %%
#Reemplazamos valores "\N"
races_df = races_df.replace("\\N", "NoData")

# %%
races_df
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 0          1  2009      1          1     Australian Grand Prix  2009-03-29
# 1          2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4        Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                       ...         ...
# 1053    1069  2021     18         69  United States Grand Prix  2021-10-24
# 1054    1070  2021     19         32    Mexico City Grand Prix  2021-10-31
# 1055    1071  2021     20         18      Brazilian Grand Prix  2021-11-07
# 1056    1072  2021     22         77  Saudi Arabian Grand Prix  2021-12-05
# 1057    1073  2021     23         24      Abu Dhabi Grand Prix  2021-12-12
#
#           time                                                url
# ...

# %%
#Convertimos el Dataframe a csv

races_df.to_csv('races.csv', index=False)

# %% [markdown]
# ### Normalizando los Datasets: Qualifying_split

# %%
qs1df = pd.read_csv(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\Qualifying\qualifying_split_1.csv")
qs2df = pd.read_csv(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\Qualifying\qualifying_split_2.csv")

# %%
# En este caso tenemos dos archivos con la misma cantidad de columnas y designadas con el mismo nombre
# Revisamos si hay valores nulos
qs1df
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0             1      18         1              1      22         1  1:26.572
# 1             2      18         9              2       4         2  1:26.103
# 2             3      18         5              1      23         3  1:25.664
# 3             4      18        13              6       2         4  1:25.994
# 4             5      18         2              2       3         5  1:25.960
# ...         ...     ...       ...            ...     ...       ...       ...
# 4994       4997     861         3            131       8         8  1:37.696
# 4995       4998     861         4              6       5         9  1:38.151
# 4996       4999     861       815             15      15        10  1:37.933
# 4997       5000     861       813              3      18        11  1:37.789
# 4998       5001     861        13              6       6        12  1:38.381
#
#             q2        q3
# ...

# %%
qs1df.isnull().sum()
# Out:
# qualifyId         0
# raceId            0
# driverId          0
# constructorId     0
# number            0
# position          0
# q1                0
# q2               19
# q3               19
# dtype: int64

# %%
#Tenemos valores nulos, por lo que reemplazamos estos valores en las dos columnas en donde se encuentran.
qs1df.fillna("NoData", inplace = True)

# %%
#Confirmamos el reemplazo
qs1df.isnull().sum()
# Out:
# qualifyId        0
# raceId           0
# driverId         0
# constructorId    0
# number           0
# position         0
# q1               0
# q2               0
# q3               0
# dtype: int64

# %%
##Buscamos valores de forma "\N"
'\\N' in qs1df.values
# Out:
# True

# %%
#Reemplazamos valores "\N"
qs1df = qs1df.replace("\\N", "NoData")

# %%
#Buscamos valores duplicados
qs1df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4994    False
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# Length: 4999, dtype: bool

# %%
#Pasamos a convertir a .csv este dataframe ya limpio

qs1df.to_csv('Qualifying_split1.csv', index=False)

# %%
#Realizamos el mismo procedimiento para el dataframe qs2df
qs2df
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          5002     861       811              3      19        13  1:38.437
# 1          5003     861       814             10      11        14  1:38.325
# 2          5004     861       817              5      16        15  1:38.419
# 3          5005     861       807             10      12        16  1:38.303
# 4          5006     861       155             15      14        17  1:38.372
# ...         ...     ...       ...            ...     ...       ...       ...
# 3690       8730    1047         8             51       7        16  1:37.555
# 3691       8731    1047       825            210      20        17  1:37.863
# 3692       8732    1047       847              3      63        18  1:38.045
# 3693       8733    1047       850            210      51        19  1:38.173
# 3694       8734    1047       849              3       6        20  1:38.443
#
#             q2  q3
# 0     1:37.841  \N
# ...

# %%
qs2df.isnull().sum()
# Out:
# qualifyId          0
# raceId             0
# driverId           0
# constructorId      0
# number             0
# position           0
# q1                 8
# q2               115
# q3               236
# dtype: int64

# %%
#Tenemos valores nulos, por lo que reemplazamos estos valores en las dos columnas en donde se encuentran.
qs2df.fillna("NoData", inplace = True)

# %%
qs2df.isnull().sum()
# Out:
# qualifyId        0
# raceId           0
# driverId         0
# constructorId    0
# number           0
# position         0
# q1               0
# q2               0
# q3               0
# dtype: int64

# %%
#Buscamos valores de forma "\N"
'\\N' in qs2df.values
# Out:
# True

# %%
#Reemplazamos valores "\N"
qs2df = qs2df.replace("\\N", "NoData")

# %%
#Buscamos valores duplicados
qs2df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3690    False
# 3691    False
# 3692    False
# 3693    False
# 3694    False
# Length: 3695, dtype: bool

# %%
#Pasamos a convertir a .csv este dataframe ya limpio

qs2df.to_csv('Qualifying_split2.csv', index=False)

# %%
qs2df
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          5002     861       811              3      19        13  1:38.437
# 1          5003     861       814             10      11        14  1:38.325
# 2          5004     861       817              5      16        15  1:38.419
# 3          5005     861       807             10      12        16  1:38.303
# 4          5006     861       155             15      14        17  1:38.372
# ...         ...     ...       ...            ...     ...       ...       ...
# 3690       8730    1047         8             51       7        16  1:37.555
# 3691       8731    1047       825            210      20        17  1:37.863
# 3692       8732    1047       847              3      63        18  1:38.045
# 3693       8733    1047       850            210      51        19  1:38.173
# 3694       8734    1047       849              3       6        20  1:38.443
#
#             q2      q3
# ...

# %%
#Unimos los datasets Q1 y Q2

qualifying = pd.concat([qs1df, qs2df], ignore_index = True)

# %%
qualifying
# Out:
#       qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0             1      18         1              1      22         1  1:26.572
# 1             2      18         9              2       4         2  1:26.103
# 2             3      18         5              1      23         3  1:25.664
# 3             4      18        13              6       2         4  1:25.994
# 4             5      18         2              2       3         5  1:25.960
# ...         ...     ...       ...            ...     ...       ...       ...
# 8689       8730    1047         8             51       7        16  1:37.555
# 8690       8731    1047       825            210      20        17  1:37.863
# 8691       8732    1047       847              3      63        18  1:38.045
# 8692       8733    1047       850            210      51        19  1:38.173
# 8693       8734    1047       849              3       6        20  1:38.443
#
#             q2        q3
# ...

# %%
#Pasamos a convertir a .csv este dataframe ya limpio

qualifying.to_csv('Qualifying.csv', index=False)

# %% [markdown]
# ### Normalizando los Datasets: LapTimes

# %%
#Cargamos los datasets
laptimes1df = pd.read_csv(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\lap_times\lap_times_split_1.csv")
laptimes2df = pd.read_csv(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\lap_times\lap_times_split_2.csv")
laptimes3df = pd.read_csv(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\lap_times\lap_times_split_3.csv")
laptimes4df = pd.read_csv(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\lap_times\lap_times_split_4.csv")
laptimes5df = pd.read_csv(r"C:\Users\Mimar\Desktop\SoyHenry\PIindividuales\Repo01\Proyecto_i1\Datasets\lap_times\lap_times_split_5.csv")

# %%
#Agregamos nombres a las columnas
laptimes1df.columns = ["RaceId", "DriverId", "Lap", "Position", "Time","Miliseconds"]
laptimes2df.columns = ["RaceId", "DriverId", "Lap", "Position", "Time","Miliseconds"]
laptimes3df.columns = ["RaceId", "DriverId", "Lap", "Position", "Time","Miliseconds"]
laptimes4df.columns = ["RaceId", "DriverId", "Lap", "Position", "Time","Miliseconds"]
laptimes5df.columns = ["RaceId", "DriverId", "Lap", "Position", "Time","Miliseconds"]
laptimes1df
# Out:
#        RaceId  DriverId  Lap  Position      Time  Miliseconds
# 0         841        20    2         1  1:33.006        93006
# 1         841        20    3         1  1:32.713        92713
# 2         841        20    4         1  1:32.803        92803
# 3         841        20    5         1  1:32.342        92342
# 4         841        20    6         1  1:32.605        92605
# ...       ...       ...  ...       ...       ...          ...
# 99993     933       830   42         7  1:13.273        73273
# 99994     933       830   43         7  1:13.104        73104
# 99995     933       830   44         7  1:13.095        73095
# 99996     933       830   45         7  1:13.076        73076
# 99997     933       830   46         7  1:13.273        73273
#
# [99998 rows x 6 columns]

# %%
#Unimos los dataframes pertenecientes al mismo dataset
laptimes = pd.concat([laptimes1df,laptimes2df,laptimes3df,laptimes4df,laptimes5df], ignore_index = True)
laptimes
# Out:
#         RaceId  DriverId  Lap  Position      Time  Miliseconds
# 0          841        20    2         1  1:33.006        93006
# 1          841        20    3         1  1:32.713        92713
# 2          841        20    4         1  1:32.803        92803
# 3          841        20    5         1  1:32.342        92342
# 4          841        20    6         1  1:32.605        92605
# ...        ...       ...  ...       ...       ...          ...
# 490894    1047       815    4        17  1:44.762       104762
# 490895    1047       815    5        16  1:43.786       103786
# 490896    1047       815    6        15  1:43.263       103263
# 490897    1047       815    7        15  1:45.123       105123
# 490898    1047       815    8        14  1:44.231       104231
#
# [490899 rows x 6 columns]

# %%
#Realizamos el proceso de revisar valores duplicados y de valores faltantes.

#Buscamos valores duplicados
laptimes.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 490894    False
# 490895    False
# 490896    False
# 490897    False
# 490898    False
# Length: 490899, dtype: bool

# %%
#Buscamos valores de forma "\N"
'\\N' in qs2df.values
# Out:
# False

# %%
#Pasamos a convertir a .csv este dataframe ya limpio

laptimes.to_csv('LapTimes.csv', index=False)
